# %%
import pandas as pd

# %%
df=pd.read_csv('data/survey_results_public.csv',index_col='ResponseId')
schema_df=pd.read_csv('data/survey_results_schema.csv',index_col='qname')

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
df['ConvertedCompYearly'].head(15)
# Out:
# ResponseId
# 1     62268.0
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10    51552.0
# 11        NaN
# 12    46482.0
# 13    77290.0
# 14        NaN
# 15        NaN
# Name: ConvertedCompYearly, dtype: float64

# %%
df['ConvertedCompYearly'].median()
# Out:
# 56211.0

# %%
df.median()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_5640\3856079650.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median(numeric_only=None)
# CompTotal              67000.0
# ConvertedCompYearly    56211.0
# dtype: float64

# %%
df.describe()
#it will show the all aggregation
# Out:
#           CompTotal  ConvertedCompYearly
# count  4.718300e+04         4.684400e+04
# mean   2.119407e+69         1.184262e+05
# std    4.603702e+71         5.272944e+05
# min    0.000000e+00         1.000000e+00
# 25%    1.600000e+04         2.702500e+04
# 50%    6.700000e+04         5.621100e+04
# 75%    1.400000e+05         1.000000e+05
# max    1.000000e+74         4.524131e+07

# %%
#mean is affected heaviely by outliers so medians are prefered.

# %%
#people who have  answered the question of salary

# %%
df['ConvertedCompYearly'].count()
# Out:
# 46844

# %%
#ie 46844 students have answered the question for the salary in the given survey

# %%
df['Gender']
# Out:
# ResponseId
# 1        Man
# 2        Man
# 3        Man
# 4        Man
# 5        Man
#         ...
# 83435    Man
# 83436    Man
# 83437    Man
# 83438    Man
# 83439    Man
# Name: Gender, Length: 83439, dtype: object

# %%
df['Gender'].value_counts()
# Out:
# Man                                                                                   74817
# Woman                                                                                  4120
# Prefer not to say                                                                      1442
# Non-binary, genderqueer, or gender non-conforming                                       690
# Or, in your own words:                                                                  413
# Man;Or, in your own words:                                                              268
# Man;Non-binary, genderqueer, or gender non-conforming                                   252
# Woman;Non-binary, genderqueer, or gender non-conforming                                 147
# Man;Woman                                                                                41
# Non-binary, genderqueer, or gender non-conforming;Or, in your own words:                 21
# ...

# %%
df.columns
# Out:
# Index(['MainBranch', 'Employment', 'Country', 'US_State', 'UK_Country',
#        'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode', 'YearsCodePro',
#        'DevType', 'OrgSize', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df['LanguageHaveWorkedWith']
# Out:
# ResponseId
# 1        C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 2                                    JavaScript;Python
# 3                             Assembly;C;Python;R;Rust
# 4                                JavaScript;TypeScript
# 5                       Bash/Shell;HTML/CSS;Python;SQL
#                              ...
# 83435                               Clojure;Kotlin;SQL
# 83436                                              NaN
# 83437                               Groovy;Java;Python
# 83438             Bash/Shell;JavaScript;Node.js;Python
# 83439           Delphi;Elixir;HTML/CSS;Java;JavaScript
# Name: LanguageHaveWorkedWith, Length: 83439, dtype: object

# %%
df['LanguageHaveWorkedWith'].value_counts()
# Out:
# Python                                                                                                 1337
# HTML/CSS;JavaScript;Node.js;TypeScript                                                                  811
# Java                                                                                                    715
# HTML/CSS;JavaScript;PHP;SQL                                                                             674
# C#                                                                                                      597
#                                                                                                        ...
# Assembly;Bash/Shell;C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Kotlin;Node.js;Perl;PHP;Python;SQL;VBA       1
# C#;C++;Dart;Go;JavaScript;Node.js;SQL;TypeScript                                                          1
# Bash/Shell;C;C++;Groovy;HTML/CSS;Java;JavaScript;Node.js;SQL;TypeScript                                   1
# ...

# %%
df['LanguageHaveWorkedWith'].value_counts(normalize=True)
# Out:
# Python                                                                                                 0.016234
# HTML/CSS;JavaScript;Node.js;TypeScript                                                                 0.009847
# Java                                                                                                   0.008682
# HTML/CSS;JavaScript;PHP;SQL                                                                            0.008184
# C#                                                                                                     0.007249
#                                                                                                          ...
# Assembly;Bash/Shell;C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Kotlin;Node.js;Perl;PHP;Python;SQL;VBA    0.000012
# C#;C++;Dart;Go;JavaScript;Node.js;SQL;TypeScript                                                       0.000012
# ...

# %%
#normalize equals zero is used to see the results the percentage for series not for dataframes

# %%
#GROUPING

# %%
# Group by operation involves some combinaion of spliting the object applying a fution and then combining the results.

# %%
#GROUPING= SPLIT   +   APPLY FUNCTION  +  COMBINE RESULTS

# %%
df['Country']
# Out:
# ResponseId
# 1                                                 Slovakia
# 2                                              Netherlands
# 3                                       Russian Federation
# 4                                                  Austria
# 5        United Kingdom of Great Britain and Northern I...
#                                ...
# 83435                             United States of America
# 83436                                                Benin
# 83437                             United States of America
# 83438                                               Canada
# 83439                                               Brazil
# Name: Country, Length: 83439, dtype: object

# %%
df['Country'].value_counts()
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Saint Kitts and Nevis                                       1
# Dominica                                                    1
# Saint Vincent and the Grenadines                            1
# Tuvalu                                                      1
# Papua New Guinea                                            1
# Name: Country, Length: 181, dtype: int64

# %%
#Grouping

# %%
country_grp=df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#                                         MainBranch          Employment  \
# ResponseId
# 9                   I am a developer by profession  Employed part-time
# 23          I am a student who is learning to code  Student, full-time
# 40          I am a student who is learning to code  Student, part-time
# 50          I am a student who is learning to code  Student, full-time
# 53                  I am a developer by profession  Employed full-time
# ...                                            ...                 ...
# 83400               I am a developer by profession  Employed full-time
# 83407       I am a student who is learning to code  Student, full-time
# 83411       I am a student who is learning to code  Student, part-time
# 83412               I am a developer by profession  Employed full-time
# 83418               I am a developer by profession  Student, full-time
#
#            Country US_State UK_Country  \
# ResponseId
# 9            India      NaN        NaN
# ...

# %%
# it is same like creationg the filtering and calling

# %%
filt=df['Country']=='India'

# %%
df.loc[filt]
# Out:
#                                         MainBranch          Employment  \
# ResponseId
# 9                   I am a developer by profession  Employed part-time
# 23          I am a student who is learning to code  Student, full-time
# 40          I am a student who is learning to code  Student, part-time
# 50          I am a student who is learning to code  Student, full-time
# 53                  I am a developer by profession  Employed full-time
# ...                                            ...                 ...
# 83400               I am a developer by profession  Employed full-time
# 83407       I am a student who is learning to code  Student, full-time
# 83411       I am a student who is learning to code  Student, part-time
# 83412               I am a developer by profession  Employed full-time
# 83418               I am a developer by profession  Student, full-time
#
#            Country US_State UK_Country  \
# ResponseId
# 9            India      NaN        NaN
# ...

# %%
filt=df['Country']=='India'
df.loc[filt]['LanguageHaveWorkedWith'].value_counts()
# Out:
# Python                                                             292
# Java                                                               201
# HTML/CSS;JavaScript;Node.js;TypeScript                             112
# HTML/CSS;JavaScript                                                110
# HTML/CSS;JavaScript;Node.js                                         99
#                                                                   ...
# C;C#;HTML/CSS;JavaScript;Node.js;TypeScript                          1
# Java;JavaScript;Kotlin;Node.js;Objective-C;SQL;Swift;TypeScript      1
# Go;Java;JavaScript;Node.js;Python;Scala;SQL                          1
# APL;HTML/CSS;Java;JavaScript;R;SQL                                   1
# Bash/Shell;C;C++;Java;SQL                                            1
# Name: LanguageHaveWorkedWith, Length: 4248, dtype: int64

# %%
#filtering will give the count for only one country it cannot give result for multiple country

# %%
country_grp['LanguageHaveWorkedWith'].value_counts()
# Out:
# Country      LanguageHaveWorkedWith
# Afghanistan  APL                                                                                                                                                                                                                                                  3
#              APL;Assembly;Bash/Shell;C;C#;C++;Clojure;COBOL;Crystal;Dart;Delphi;Elixir;Erlang;F#;Go;Groovy;Haskell;HTML/CSS;Java;JavaScript;Julia;Kotlin;LISP;Matlab;Node.js;Objective-C;Perl;PHP;PowerShell;Python;R;Ruby;Rust;Scala;SQL;Swift;TypeScript;VBA    2
#              Bash/Shell                                                                                                                                                                                                                                           2
# ...

# %%
#grouping allows us to see the count for the many countries

# %%
country_grp['LanguageHaveWorkedWith'].value_counts().loc['India']
# Out:
# LanguageHaveWorkedWith
# Python                                    292
# Java                                      201
# HTML/CSS;JavaScript;Node.js;TypeScript    112
# HTML/CSS;JavaScript                       110
# HTML/CSS;JavaScript;Node.js                99
#                                          ...
# Python;Swift                                1
# Python;VBA                                  1
# R;Swift                                     1
# R;VBA                                       1
# Swift;TypeScript                            1
# Name: LanguageHaveWorkedWith, Length: 4248, dtype: int64

# %%
# IT IS IMPORTANT BECAUSE NOW WE CAN SEE THIS RESULT FOR ANY COUNTRY WITHOUT RUNNING A FILTER ON EACH INDIVIDUAL COUNTRY IN THE WORLD

# %%
country_grp['ConvertedCompYearly'].median().loc['Nepal']
# Out:
# 7884.0

# %%
country_grp['ConvertedCompYearly'].agg(['median','mean'])
# Out:
#                                        median          mean
# Country
# Afghanistan                            9792.0  2.794748e+06
# Albania                               15900.0  4.499814e+04
# Algeria                                9875.0  1.446114e+04
# Andorra                               94045.5  8.928200e+04
# Angola                                 9750.0  2.155680e+04
# ...                                       ...           ...
# Venezuela, Bolivarian Republic of...  12000.0  2.246505e+04
# Viet Nam                              12678.0  1.995289e+04
# Yemen                                  3954.0  5.628667e+03
# Zambia                                 9816.0  1.991491e+04
# Zimbabwe                               7200.0  1.141477e+04
#
# [181 rows x 2 columns]

# %%
country_grp['ConvertedCompYearly'].agg(['median','mean']).loc['Nepal']
# Out:
# median     7884.000000
# mean      15069.541284
# Name: Nepal, dtype: float64

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x:x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              20
# Albania                                  30
# Algeria                                  19
# Andorra                                   4
# Angola                                    5
#                                        ...
# Venezuela, Bolivarian Republic of...     43
# Viet Nam                                173
# Yemen                                     6
# Zambia                                   12
# Zimbabwe                                 17
# Name: LanguageHaveWorkedWith, Length: 181, dtype: int64

# %%
# to display this things in percentage

# %%
country_respondents=df['Country'].value_counts()

# %%
country_respondents
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Saint Kitts and Nevis                                       1
# Dominica                                                    1
# Saint Vincent and the Grenadines                            1
# Tuvalu                                                      1
# Papua New Guinea                                            1
# Name: Country, Length: 181, dtype: int64

# %%
country_uses_python=country_grp['LanguageHaveWorkedWith'].apply(lambda x:x.str.contains('Python').sum())

# %%
country_uses_python
# Out:
# Country
# Afghanistan                              20
# Albania                                  30
# Algeria                                  19
# Andorra                                   4
# Angola                                    5
#                                        ...
# Venezuela, Bolivarian Republic of...     43
# Viet Nam                                173
# Yemen                                     6
# Zambia                                   12
# Zimbabwe                                 17
# Name: LanguageHaveWorkedWith, Length: 181, dtype: int64

# %%
python_df=pd.concat([country_respondents,country_uses_python],axis='columns',sort=False)

# %%
python_df
# Out:
#                                                     Country  \
# United States of America                              15288
# India                                                 10511
# Germany                                                5625
# United Kingdom of Great Britain and Northern Ir...     4475
# Canada                                                 3012
# ...                                                     ...
# Saint Kitts and Nevis                                     1
# Dominica                                                  1
# Saint Vincent and the Grenadines                          1
# Tuvalu                                                    1
# Papua New Guinea                                          1
#
#                                                     LanguageHaveWorkedWith
# United States of America                                              7975
# India                                                                 5233
# ...

# %%
python_df['PerknowPython']=(python_df['LanguageHaveWorkedWith']/python_df['Country'])*100

# %%
python_df
# Out:
#                                                     Country  \
# United States of America                              15288
# India                                                 10511
# Germany                                                5625
# United Kingdom of Great Britain and Northern Ir...     4475
# Canada                                                 3012
# ...                                                     ...
# Saint Kitts and Nevis                                     1
# Dominica                                                  1
# Saint Vincent and the Grenadines                          1
# Tuvalu                                                    1
# Papua New Guinea                                          1
#
#                                                     LanguageHaveWorkedWith  \
# United States of America                                              7975
# India                                                                 5233
# ...

# %%
python_df.sort_values(by=['PerknowPython'],ascending=False)
# Out:
#                                   Country  LanguageHaveWorkedWith  \
# Tuvalu                                  1                       1
# Brunei Darussalam                       1                       1
# Sierra Leone                            2                       2
# Dominica                                1                       1
# Liechtenstein                           1                       1
# ...                                   ...                     ...
# Mali                                    2                       0
# Saint Kitts and Nevis                   1                       0
# Saint Vincent and the Grenadines        1                       0
# Lesotho                                 4                       0
# Papua New Guinea                        1                       0
#
#                                   PerknowPython
# Tuvalu                                    100.0
# Brunei Darussalam                         100.0
# ...
