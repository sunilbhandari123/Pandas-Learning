# %%
import pandas as pd

# %%
na_vals=['NA','Missing']
df=pd.read_csv('data/survey_results_public.csv',index_col='ResponseId',na_values=na_vals)
schema_df=pd.read_csv('data/survey_results_schema.csv',index_col='qname')

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
# now lets see the years of code column

# %%
df['YearsCode'].head(10)
# Out:
# ResponseId
# 1     NaN
# 2       7
# 3     NaN
# 4     NaN
# 5      17
# 6     NaN
# 7       3
# 8       4
# 9       6
# 10      7
# Name: YearsCode, dtype: object

# %%
#lets try to find the mean yearsofcode

# %%
#df['YearsCode'].mean()
#this will not work because the input is string

# %%
#df['YearsCode']=df["YearsCode"].astype(float)
# it also shows error lets find out why

# %%
df.dtypes
# Out:
# MainBranch                       object
# Employment                       object
# Country                          object
# US_State                         object
# UK_Country                       object
# EdLevel                          object
# Age1stCode                       object
# LearnCode                        object
# YearsCode                        object
# YearsCodePro                     object
# DevType                          object
# OrgSize                          object
# Currency                         object
# CompTotal                       float64
# CompFreq                         object
# LanguageHaveWorkedWith           object
# LanguageWantToWorkWith           object
# DatabaseHaveWorkedWith           object
# DatabaseWantToWorkWith           object
# PlatformHaveWorkedWith           object
# PlatformWantToWorkWith           object
# WebframeHaveWorkedWith           object
# WebframeWantToWorkWith           object
# ...

# %%
#to see inside the yearscode we should do

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '7', '17', '3', '4', '6', '16', '12', '15', '10', '40', '9',
#        '26', '14', '39', '20', '8', '19', '5', 'Less than 1 year', '22',
#        '2', '1', '34', '21', '13', '25', '24', '30', '31', '18', '38',
#        'More than 50 years', '27', '41', '42', '35', '23', '28', '11',
#        '37', '44', '43', '36', '33', '45', '29', '50', '46', '32', '47',
#        '49', '48'], dtype=object)

# %%
#there is less than 1 year and more than 50 years so we are getting the errors

#therefore we need to change it into the type int

# %%
#lets change less than 1 year and more than 50 years to 0 and 51 respectively

# %%
df['YearsCode'].replace('Less than 1 year','0',inplace=True)

# %%
df['YearsCode'].replace('More than 50 years','51',inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '7', '17', '3', '4', '6', '16', '12', '15', '10', '40', '9',
#        '26', '14', '39', '20', '8', '19', '5', '0', '22', '2', '1', '34',
#        '21', '13', '25', '24', '30', '31', '18', '38', '51', '27', '41',
#        '42', '35', '23', '28', '11', '37', '44', '43', '36', '33', '45',
#        '29', '50', '46', '32', '47', '49', '48'], dtype=object)

# %%
df['YearsCode']=df["YearsCode"].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 12.338200169032717

# %%
df['YearsCode'].median()
# Out:
# 10.0
